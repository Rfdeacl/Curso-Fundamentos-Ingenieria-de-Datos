# %%
import pandas as pd
import  openpyxl
import lxml

# %%
archivo_excel =pd.read_excel("Real Mayo 2025.xlsx")
print(archivo_excel.head(5))
# Out:
#    ID EMPLEADO                              NOMBRE    UBICACION WORKDAY  \
# 0      3489655     BRICENO CARRASCO, PEDRO ANTONIO  Contrato Candelaria
# 1      3489429       BRICENO ZEPEDA, MARIA CECILIA  Contrato Candelaria
# 2      3482213      CAMPILLAY MOLINA, SANDRA MIRNA  Contrato Candelaria
# 3      3488564     CASTILLO GALEAS, RODRIGO ANDRES  Contrato Candelaria
# 4      3492567  CISTERNA PASTENES, DAVID ALEJANDRO  Contrato Candelaria
#
#   CENTRO COSTO                 POSICION    Contrato                    Cargo  \
# 0    508321MSB  Ingeniero Planificacion  Candelaria  Ingeniero Planificación
# 1    508322MSB              Programador  Candelaria              Programador
# 2    508321MSB              Programador  Candelaria              Programador
# 3    508321MSB             Planificador  Candelaria  Ingeniero Planificación
# 4    508321MSB              Programador  Candelaria              Programador
#
#          Tipo           Área     División
# ...

# %%
archivo_html =pd.read_html("https://es.wikipedia.org/wiki/Regiones_de_Chile")
print(archivo_html)
# Out:
# [                                              Región  \
# 0                              Provincia (1928-1974)
# 1  Arica y Parinacota Tarapacá Antofagasta Atacam...
# 2                                               País
# 3                                        Creados por
# 4                                  Fecha de creación
# 5                                 Datos estadísticos
# 6                                      Número actual
# 7                                           Gobierno
# 8                                    Subdivisión(es)
# 9                         [editar datos en Wikidata]
#
#                                             Región.1  \
# 0                              Provincia (1928-1974)
# 1  Arica y Parinacota Tarapacá Antofagasta Atacam...
# 2                                              Chile
# 3                          Junta Militar de Gobierno
# 4                                               1974
# 5                                 Datos estadísticos
# ...

# %%
archivo_excel.to_csv("Realmayo 2025.csv")
archivo_csv=pd.read_csv("Realmayo 2025.csv")
print(archivo_csv)
# Out:
#     Unnamed: 0  ID EMPLEADO                              NOMBRE  \
# 0            0      3489655     BRICENO CARRASCO, PEDRO ANTONIO
# 1            1      3489429       BRICENO ZEPEDA, MARIA CECILIA
# 2            2      3482213      CAMPILLAY MOLINA, SANDRA MIRNA
# 3            3      3488564     CASTILLO GALEAS, RODRIGO ANDRES
# 4            4      3492567  CISTERNA PASTENES, DAVID ALEJANDRO
# ..         ...          ...                                 ...
# 80          80      3482370          CORDERO MEGO, CAROL AURORA
# 81          81      3485185                   POLEO TOLON, JOSE
# 82          82      3490064         TAPIA BRITO, MARLENE LORENA
# 83          83      3480442     VALDIVIA MIRANDA, BORIS ALBERTO
# 84          84      3479772        VARGAS PUELLES, LUIS EDGARDO
#
#           UBICACION WORKDAY CENTRO COSTO                 POSICION  \
# 0       Contrato Candelaria    508321MSB  Ingeniero Planificacion
# ...
